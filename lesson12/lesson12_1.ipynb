# %% [markdown]
# https://www.perplexity.ai/search/88657a74-a8c6-49a9-b9cf-0884a64ac45d

# %%
# %pip install wget
# Out:
# Requirement already satisfied: wget in /opt/miniconda3/envs/chihlee1/lib/python3.10/site-packages (3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
#下載中文字型
import wget
wget.download("https://github.com/roberthsu2003/machine_learning/raw/refs/heads/main/source_data/ChineseFont.ttf")
# Out:
# 'ChineseFont (1).ttf'

# %%
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font', family="ChineseFont")

# %%
import math
import numpy as np
from numpy import ndarray
import matplotlib.pyplot as plt

t:ndarray = np.arange(0, 2.5, 0.1)
# t.ndim
# t.size
# t.shape
# t.dtype
#print(t)
y1:ndarray = np.sin(t * math.pi)
y2:ndarray = np.sin(t * math.pi + math.pi/2)
y3:ndarray = np.sin(t * math.pi - math.pi/2)
figure, axes = plt.subplots()
axes.plot(t, y1,marker='*',linestyle=':',label="90",color="red")
axes.plot(t, y2,marker='s',linestyle='-',label="0", color="blue")
axes.plot(t, y3,marker='^',linestyle='--',label="-90",color="green")
axes.legend(loc='upper right', bbox_to_anchor=(1.18, 0.5))
axes.set_title("sin()的正弦波")
axes.set_xlabel("圓周率")
axes.set_ylabel("正弦波值")
plt.show()
